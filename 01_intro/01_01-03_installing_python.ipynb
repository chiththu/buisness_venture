# %%
###what is a string in python?
    ### a string is a sequence of character used to store text
    #string is written inside quotes;
    #single quotes''
    #double quotes ""
    #triple quotes """"
#2.what does upper () method do?
#the upper method in python is used to convert all characters in a string to uppercase
#3.what does lower() method doi?
#used to convert all characters in a string to lowercase
#4.what are string method in python?
#string methods are built in functions used to perform operations on strings
#5.what is the use of title() method?
#to convert the first letter of each word in to uppercase.
#6.captilized() method?
#to convert only  the first character of the string in to upper case and all the other characters in to the lowercase.
#7.strip() method?
#used to remove unwanted spaces from the beginning and end of the string.
#8.replace() method?
#to replace part of string in to another value
#9.split() method?
#break a string in to a list of smaller parts.
#10.find() metnod return?
#to search for a substring inside a string.
#11.count() method?
#to count how many times a substring appears in a string.
#12.startswith() method check?
#to check whether the string is stars with specific value.
#13.endswith() method check?
#to check whether the string is ends with  specific value.
#14.len() function return for a string?
#to find the length of the string.
#15.how do you check the length of the string?>
#by using the len() function.



###codes###
a=10
b=5
print(a-b)
# Out:
# 5

# %%
a=10
b=5
print(a*b)
# Out:
# 50

# %%
a=10
b=5
print(a/b)
# Out:
# 2.0

# %%
#modulas remainder
a=17
b=5
print(a%b)
# Out:
# 2

# %%
#exponent operator
a=3
b=2
print(a**b)
# Out:
# 9

# %%
#floor division between two number
a=10
b=4
print(a//b)
# Out:
# 2

# %%
#sum of three numbers
a=1
b=2
c=3
print(a+b+c)
# Out:
# 6

# %%
#average of ttwo numbers
a=8
b=2
print((a+b)/2)
# Out:
# 5.0
